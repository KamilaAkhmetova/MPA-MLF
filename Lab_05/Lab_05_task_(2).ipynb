# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](img/network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# *In* this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
# X = [[0, 0], [0, 1], [1, 0], [1, 1]]
# y = [0, 1, 1, 0]

# %%
import numpy as np
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0,1,1,0])

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell
#
# > Add blockquote

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2,)))
# added kernel_initializer
model.add(Dense(2, activation='sigmoid', kernel_initializer='glorot_uniform'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# **To** compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(X, y, epochs=1000, batch_size=1, verbose=0)

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 100.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  # data_sample = np.array(data_sample)
  prediction = model.predict(data_sample.reshape(1,-1))
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Data sample is [0 0], prediction from model [[0.6526245]], ground_truth 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Data sample is [0 1], prediction from model [[0.6561093]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Data sample is [1 0], prediction from model [[0.6572686]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Data sample is [1 1], prediction from model [[0.6559949]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = 'sample_data/voting_complete.csv'
pd_dataset = pd.read_csv(path_to_dataset)

# %%
pd_dataset
# Out:
#      Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0             0  republican                   n                          y
# 1             1  republican                   n                          y
# 2             2    democrat                   ?                          y
# 3             3    democrat                   n                          y
# 4             4    democrat                   y                          y
# ..          ...         ...                 ...                        ...
# 430         430  republican                   n                          n
# 431         431    democrat                   n                          n
# 432         432  republican                   n                          ?
# 433         433  republican                   n                          n
# 434         434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 18 columns]

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %%
# 1 it is a classification task
print(pd_dataset['Class Name'].unique())
# Out:
# ['republican' 'democrat']

# %%
# 2
print(pd_dataset.shape[0])
# Out:
# 435

# %%
# 3 there are 16 because there are 2 additional columns
print(pd_dataset.shape[1])
# Out:
# 18

# %%
# 4
pd_dataset.dtypes
# Out:
# Unnamed: 0                                 int64
# Class Name                                object
# handicapped-infants                       object
# water-project-cost-sharing                object
# adoption-of-the-budget-resolution         object
# physician-fee-freeze                      object
# el-salvador-aid                           object
# religious-groups-in-schools               object
# anti-satellite-test-ban                   object
# aid-to-nicaraguan-contras                 object
# mx-missile                                object
# immigration                               object
# synfuels-corporation-cutback              object
# education-spending                        object
# superfund-right-to-sue                    object
# crime                                     object
# duty-free-exports                         object
# export-administration-act-south-africa    object
# dtype: object

# %%
# 5 Yes, there are missing values
pd_dataset.replace('?', np.nan, inplace=True)
missing_values = pd_dataset.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0                                  0
# Class Name                                  0
# handicapped-infants                        12
# water-project-cost-sharing                 48
# adoption-of-the-budget-resolution          11
# physician-fee-freeze                       11
# el-salvador-aid                            15
# religious-groups-in-schools                11
# anti-satellite-test-ban                    14
# aid-to-nicaraguan-contras                  15
# mx-missile                                 22
# immigration                                 7
# synfuels-corporation-cutback               21
# education-spending                         31
# superfund-right-to-sue                     25
# crime                                      17
# duty-free-exports                          28
# export-administration-act-south-africa    104
# dtype: int64

# %%
# 6 there are 2 labels
print(pd_dataset['Class Name'].unique())
# Out:
# ['republican' 'democrat']

# %%
# pd_dataset.describe()
# Out:
#        Unnamed: 0
# count  435.000000
# mean   217.000000
# std    125.717938
# min      0.000000
# 25%    108.500000
# 50%    217.000000
# 75%    325.500000
# max    434.000000

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     y                          y
# 3                     n                          y
# 4                     n                          y
# ..                  ...                        ...
# 343                   y                          n
# 344                   n                          n
# 345                   n                          ?
# 346                   n                          n
# 347                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   y                    n               ?
# 2                                   y                    n               y
# 3                                   n                    y               y
# 4                                   n                    y               y
# ..                                ...                  ...             ...
# 343                                 y                    n               ?
# 344                                 y                    n               n
# 345                                 n                    y               y
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 343                           n                       y
# 344                           n                       y
# 345                           y                       n
# 346                           y                       ?
# 347                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 343                         y          y           y
# 344                         y          y           y
# 345                         n          n           n
# 346                         ?          ?           ?
# 347                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              y                  n                      y
# 2                              y                  ?                      y
# 3                              n                  n                      ?
# 4                              n                  n                      y
# ..                           ...                ...                    ...
# 343                            n                  y                      n
# 344                            n                  n                      n
# 345                            y                  y                      y
# 346                            n                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       n                 n                                      y
# 2       y                 y                                      y
# 3       y                 y                                      y
# 4       y                 ?                                      y
# ..    ...               ...                                    ...
# 343     ?                 y                                      y
# 344     n                 n                                      y
# 345     y                 n                                      y
# 346     y                 n                                      y
# 347     y                 ?                                      n
#
# [348 rows x 16 columns]

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
x_train.replace('?',np.nan, inplace=True)
x_train.fillna(x_train.mode().iloc[0], inplace=True)
x_train
x = pd.get_dummies(x_train)
# y = pd.get_dummies(y_train)
x
# Out:
#      handicapped-infants_n  handicapped-infants_y  \
# 0                     True                  False
# 1                     True                  False
# 2                     True                  False
# 3                    False                   True
# 4                     True                  False
# ..                     ...                    ...
# 343                   True                  False
# 344                   True                  False
# 345                   True                  False
# 346                   True                  False
# 347                   True                  False
#
#      water-project-cost-sharing_n  water-project-cost-sharing_y  \
# 0                           False                          True
# 1                           False                          True
# 2                           False                          True
# 3                           False                          True
# 4                           False                          True
# ..                            ...                           ...
# 343                          True                         False
# 344                          True                         False
# 345                         False                          True
# 346                          True                         False
# 347                         False                          True
#
#      adoption-of-the-budget-resolution_n  adoption-of-the-budget-resolution_y  \
# 0                                   True                                False
# 1                                   True                                False
# 2                                  False                                 True
# 3                                  False                                 True
# 4                                  False                                 True
# ..                                   ...                                  ...
# 343                                False                                 True
# 344                                False                                 True
# 345                                 True                                False
# 346                                 True                                False
# 347                                 True                                False
#
#      physician-fee-freeze_n  physician-fee-freeze_y  el-salvador-aid_n  \
# 0                     False                    True              False
# 1                     False                    True              False
# 2                      True                   False              False
# 3                      True                   False              False
# 4                      True                   False              False
# ..                      ...                     ...                ...
# 343                   False                    True              False
# 344                    True                   False               True
# 345                   False                    True              False
# 346                   False                    True              False
# 347                   False                    True              False
#
#      el-salvador-aid_y  ...  education-spending_n  education-spending_y  \
# 0                 True  ...                 False                  True
# 1                 True  ...                 False                  True
# 2                 True  ...                  True                 False
# 3                 True  ...                  True                 False
# 4                 True  ...                  True                 False
# ..                 ...  ...                   ...                   ...
# 343               True  ...                 False                  True
# 344              False  ...                  True                 False
# 345               True  ...                 False                  True
# 346               True  ...                 False                  True
# 347               True  ...                 False                  True
#
#      superfund-right-to-sue_n  superfund-right-to-sue_y  crime_n  crime_y  \
# 0                       False                      True    False     True
# 1                       False                      True    False     True
# 2                       False                      True     True    False
# 3                       False                      True    False     True
# 4                       False                      True    False     True
# ..                        ...                       ...      ...      ...
# 343                     False                      True    False     True
# 344                      True                     False     True    False
# 345                     False                      True    False     True
# 346                     False                      True    False     True
# 347                     False                      True    False     True
#
#      duty-free-exports_n  duty-free-exports_y  \
# 0                   True                False
# 1                   True                False
# 2                   True                False
# 3                  False                 True
# 4                  False                 True
# ..                   ...                  ...
# 343                 True                False
# 344                 True                False
# 345                 True                False
# 346                 True                False
# 347                 True                False
#
#      export-administration-act-south-africa_n  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 343                                     False
# 344                                     False
# 345                                     False
# 346                                     False
# 347                                      True
#
#      export-administration-act-south-africa_y
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ..                                        ...
# 343                                      True
# 344                                      True
# 345                                      True
# 346                                      True
# 347                                     False
#
# [348 rows x 32 columns]

# %%
# pd_dataset.replace('?', 'unknown', inplace=True)
# x_train = pd_dataset.drop('Class Name', axis=1)
# y_train = pd_dataset['Class Name']

# x = pd.get_dummies(x_train)
# y = pd.get_dummies(y_train)
# x
# Out:
#      Unnamed: 0  handicapped-infants_n  handicapped-infants_y  \
# 0             0                   True                  False
# 1             1                   True                  False
# 2             2                  False                  False
# 3             3                   True                  False
# 4             4                  False                   True
# ..          ...                    ...                    ...
# 430         430                   True                  False
# 431         431                   True                  False
# 432         432                   True                  False
# 433         433                   True                  False
# 434         434                   True                  False
#
#      water-project-cost-sharing_n  water-project-cost-sharing_y  \
# 0                           False                          True
# 1                           False                          True
# 2                           False                          True
# 3                           False                          True
# 4                           False                          True
# ..                            ...                           ...
# 430                          True                         False
# 431                          True                         False
# 432                         False                         False
# 433                          True                         False
# 434                         False                          True
#
#      adoption-of-the-budget-resolution_n  adoption-of-the-budget-resolution_y  \
# 0                                   True                                False
# 1                                   True                                False
# 2                                  False                                 True
# 3                                  False                                 True
# 4                                  False                                 True
# ..                                   ...                                  ...
# 430                                False                                 True
# 431                                False                                 True
# 432                                 True                                False
# 433                                 True                                False
# 434                                 True                                False
#
#      physician-fee-freeze_n  physician-fee-freeze_y  el-salvador-aid_n  ...  \
# 0                     False                    True              False  ...
# 1                     False                    True              False  ...
# 2                     False                   False              False  ...
# 3                      True                   False              False  ...
# 4                      True                   False              False  ...
# ..                      ...                     ...                ...  ...
# 430                   False                    True              False  ...
# 431                    True                   False               True  ...
# 432                   False                    True              False  ...
# 433                   False                    True              False  ...
# 434                   False                    True              False  ...
#
#      education-spending_n  education-spending_y  superfund-right-to-sue_n  \
# 0                   False                  True                     False
# 1                   False                  True                     False
# 2                    True                 False                     False
# 3                    True                 False                     False
# 4                   False                 False                     False
# ..                    ...                   ...                       ...
# 430                 False                  True                     False
# 431                  True                 False                      True
# 432                 False                  True                     False
# 433                 False                  True                     False
# 434                 False                  True                     False
#
#      superfund-right-to-sue_y  crime_n  crime_y  duty-free-exports_n  \
# 0                        True    False     True                 True
# 1                        True    False     True                 True
# 2                        True    False     True                 True
# 3                        True     True    False                 True
# 4                        True    False     True                False
# ..                        ...      ...      ...                  ...
# 430                      True    False     True                 True
# 431                     False     True    False                 True
# 432                      True    False     True                 True
# 433                      True    False     True                 True
# 434                      True    False     True                False
#
#      duty-free-exports_y  export-administration-act-south-africa_n  \
# 0                  False                                     False
# 1                  False                                     False
# 2                  False                                      True
# 3                  False                                     False
# 4                   True                                     False
# ..                   ...                                       ...
# 430                False                                     False
# 431                False                                     False
# 432                False                                     False
# 433                False                                     False
# 434                False                                      True
#
#      export-administration-act-south-africa_y
# 0                                        True
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                        True
# ..                                        ...
# 430                                      True
# 431                                      True
# 432                                      True
# 433                                      True
# 434                                     False
#
# [435 rows x 33 columns]

# %%
#WRITE YOUR CODE HERE
# y = y_train.replace({'republican':1, 'democrat':0})
# y
# Out:
# <ipython-input-51-f40cc50c67f8>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y_train.replace({'republican':1, 'democrat':0})
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 343    0
# 344    1
# 345    1
# 346    1
# 347    1
# Name: Class Name, Length: 348, dtype: int64

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# WRITE YOU CODE HERE
model = Sequential()
# added
model.add(InputLayer(input_shape=(2,)))
model.add(Dense(2,activation='sigmoid'))
# model.add(Dense(8,input_shape=(32,),activation='relu'))

# model.add(Dense(8, input_shape=(x.shape[1],),activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                     │ (None, 2)                   │               6 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer=tf.keras.optimizers.SGD(learning_rate=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# [link text](https://)4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
print(x.shape)
print(y.shape)
# Out:
# (348, 32)
# (4,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)
history = model.fit(X_train, y_train, epochs=40, batch_size=4, validation_data=(X_val, y_val))
# Out:
# Epoch 1/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step - accuracy: 0.3333 - loss: 0.7456 - val_accuracy: 1.0000 - val_loss: 0.6564
# Epoch 2/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3333 - loss: 0.7062 - val_accuracy: 0.0000e+00 - val_loss: 0.7285
# Epoch 3/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6667 - loss: 0.6793 - val_accuracy: 0.0000e+00 - val_loss: 0.7921
# Epoch 4/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6667 - loss: 0.6607 - val_accuracy: 0.0000e+00 - val_loss: 0.8476
# Epoch 5/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6667 - loss: 0.6478 - val_accuracy: 0.0000e+00 - val_loss: 0.8957
# Epoch 6/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6667 - loss: 0.6387 - val_accuracy: 0.0000e+00 - val_loss: 0.9374
# Epoch 7/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6667 - loss: 0.6322 - val_accuracy: 0.0000e+00 - val_loss: 0.9734
# Epoch 8/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6667 - loss: 0.6275 - val_accuracy: 0.0000e+00 - val_loss: 1.0046
# Epoch 9/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.6667 - loss: 0.6240 - val_accuracy: 0.0000e+00 - val_loss: 1.0316
# Epoch 10/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6667 - loss: 0.6213 - val_accuracy: 0.0000e+00 - val_loss: 1.0550
# Epoch 11/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.6667 - loss: 0.6191 - val_accuracy: 0.0000e+00 - val_loss: 1.0755
# Epoch 12/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6667 - loss: 0.6174 - val_accuracy: 0.0000e+00 - val_loss: 1.0934
# Epoch 13/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.6667 - loss: 0.6159 - val_accuracy: 0.0000e+00 - val_loss: 1.1091
# Epoch 14/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.6667 - loss: 0.6146 - val_accuracy: 0.0000e+00 - val_loss: 1.1231
# Epoch 15/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.6667 - loss: 0.6135 - val_accuracy: 0.0000e+00 - val_loss: 1.1355
# Epoch 16/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6667 - loss: 0.6124 - val_accuracy: 0.0000e+00 - val_loss: 1.1466
# Epoch 17/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6667 - loss: 0.6114 - val_accuracy: 0.0000e+00 - val_loss: 1.1566
# Epoch 18/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6667 - loss: 0.6104 - val_accuracy: 0.0000e+00 - val_loss: 1.1658
# Epoch 19/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6667 - loss: 0.6094 - val_accuracy: 0.0000e+00 - val_loss: 1.1742
# Epoch 20/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6667 - loss: 0.6085 - val_accuracy: 0.0000e+00 - val_loss: 1.1820
# Epoch 21/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6667 - loss: 0.6075 - val_accuracy: 0.0000e+00 - val_loss: 1.1893
# Epoch 22/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6667 - loss: 0.6065 - val_accuracy: 0.0000e+00 - val_loss: 1.1962
# Epoch 23/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6667 - loss: 0.6055 - val_accuracy: 0.0000e+00 - val_loss: 1.2028
# Epoch 24/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6667 - loss: 0.6045 - val_accuracy: 0.0000e+00 - val_loss: 1.2092
# Epoch 25/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6667 - loss: 0.6035 - val_accuracy: 0.0000e+00 - val_loss: 1.2154
# Epoch 26/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6667 - loss: 0.6024 - val_accuracy: 0.0000e+00 - val_loss: 1.2214
# Epoch 27/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6667 - loss: 0.6013 - val_accuracy: 0.0000e+00 - val_loss: 1.2274
# Epoch 28/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6667 - loss: 0.6002 - val_accuracy: 0.0000e+00 - val_loss: 1.2333
# Epoch 29/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6667 - loss: 0.5990 - val_accuracy: 0.0000e+00 - val_loss: 1.2392
# Epoch 30/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6667 - loss: 0.5979 - val_accuracy: 0.0000e+00 - val_loss: 1.2451
# Epoch 31/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6667 - loss: 0.5966 - val_accuracy: 0.0000e+00 - val_loss: 1.2511
# Epoch 32/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6667 - loss: 0.5954 - val_accuracy: 0.0000e+00 - val_loss: 1.2572
# Epoch 33/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6667 - loss: 0.5941 - val_accuracy: 0.0000e+00 - val_loss: 1.2633
# Epoch 34/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6667 - loss: 0.5928 - val_accuracy: 0.0000e+00 - val_loss: 1.2696
# Epoch 35/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6667 - loss: 0.5915 - val_accuracy: 0.0000e+00 - val_loss: 1.2760
# Epoch 36/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6667 - loss: 0.5901 - val_accuracy: 0.0000e+00 - val_loss: 1.2825
# Epoch 37/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6667 - loss: 0.5887 - val_accuracy: 0.0000e+00 - val_loss: 1.2893
# Epoch 38/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6667 - loss: 0.5873 - val_accuracy: 0.0000e+00 - val_loss: 1.2961
# Epoch 39/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6667 - loss: 0.5858 - val_accuracy: 0.0000e+00 - val_loss: 1.3032
# Epoch 40/40
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6667 - loss: 0.5843 - val_accuracy: 0.0000e+00 - val_loss: 1.3105

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
# WRITE YOUR CODE HERE
x_test.replace('?',np.nan, inplace=True)
x_test.fillna(x_test.mode().iloc[0], inplace=True)
# x_test
x_te = pd.get_dummies(x_test)
x_te
y_te = y_test.replace({'republican':1, 'democrat':0})
y_te
# Out:
# <ipython-input-63-c61c145902d8>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_te = y_test.replace({'republican':1, 'democrat':0})
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
#      ..
# 82    1
# 83    1
# 84    0
# 85    0
# 86    0
# Name: Class Name, Length: 87, dtype: int64

# %% [markdown]
# \2. Evaluate the model, print final accuracy and loss

# %%
model = Sequential()
# added
# model.add(InputLayer(input_shape=(2,)))
# model.add(Dense(2,activation='sigmoid'))
model.add(Dense(8,input_shape=(32,),activation='relu'))

# model.add(Dense(8, input_shape=(x.shape[1],),activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# WRITE YOUR CODE HERE
optimizer=tf.keras.optimizers.SGD(learning_rate=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# WRITE YOUR CODE HERE
loss, accuracy = model.evaluate(x_te, y_te, verbose=0)
print(accuracy*100)
print(loss*100)
# Out:
# 34.48275923728943
# 76.79376006126404

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
# sns.lineplot(x=history.epoch, y=history.history['loss'])
fig, ax = plt.subplots()
ax.plot(history.history['loss'], label='Training loss')
ax.plot(history.history['val_loss'], label='Validation loss')
ax.set_ylabel('Value')
ax.set_xlabel('Epoch')
plt.show

fig, ay = plt.subplots()
ay.plot(history.history['accuracy'], label='Training accuracy')
ay.plot(history.history['val_accuracy'], label='Validation accuracy')
ay.set_ylabel('Value')
ay.set_xlabel('Epoch')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
